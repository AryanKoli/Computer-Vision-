# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
from google.colab.patches import cv2_imshow
from PIL import Image

# %%
Image1 = cv2.imread('/content/carimage.jpg')

# %%
cv2_imshow(Image1)
# Out:
# <PIL.Image.Image image mode=RGB size=355x142>

# %%
gray_image = cv2.cvtColor(Image1, cv2.COLOR_BGR2GRAY)

cv2_imshow(gray_image)
# Out:
# <PIL.Image.Image image mode=L size=355x142>

# %%
image = Image.open('/content/carimage.jpg')
new_image = image.resize((600, 300))
new_image.save('/content/carimage_1.jpg')

# %%
new_image
# Out:
# <PIL.Image.Image image mode=RGB size=600x300>

# %%
rotated_image1 = cv2.rotate(Image1, cv2.ROTATE_90_CLOCKWISE)

# %%
cv2_imshow(rotated_image1)
# Out:
# <PIL.Image.Image image mode=RGB size=142x355>

# %%
rows, cols = new_image.shape
M = np.float32([[1, 0.5, 0], [0, 1, 0], [0, 0, 1]])
sheared_img = cv2.warpPerspective(new_image, M, (int(cols*1.5), int(rows*1.5)))
cv2_imshow('new_image', sheared_img)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-57-43559be13698> in <cell line: 1>()
# ----> 1 rows, cols = new_image.shape
#       2 M = np.float32([[1, 0.5, 0], [0, 1, 0], [0, 0, 1]])
#       3 sheared_img = cv2.warpPerspective(new_image, M, (int(cols*1.5), int(rows*1.5)))
#       4 cv2_imshow('new_image', sheared_img)
#       5
#
# /usr/local/lib/python3.10/dist-packages/PIL/Image.py in __getattr__(self, name)
#     527             deprecate("Image categories", 10, "is_animated", plural=True)
#     528             return self._category
# --> 529         raise AttributeError(name)
#     530
#     531     @property
#
# AttributeError: shape

# %%
image = Image.open('/content/no_3.png')
new_image1 = image.resize((200, 200))
new_image1.save('/content/no_3_1.png')

# %%
new_image1
# Out:
# <PIL.Image.Image image mode=P size=200x200>

# %%
image = Image.open('/content/no_5.jpg')
new_image2 = image.resize((200, 200))
new_image2.save('/content/no_5_1.jpg')

# %%
new_image2
# Out:
# <PIL.Image.Image image mode=RGB size=200x200>

# %%
import cv2
import numpy as np
from google.colab.patches import cv2_imshow
# Load the two images
image1 = cv2.imread('/content/no_3_1.png')
image2 = cv2.imread('/content/no_5_1.jpg')
# Resize the images to a common size
image1 = cv2.resize(image1, (350, 300))
image2 = cv2.resize(image2, (350, 300))
# Create frames (black backgrounds) for each image
frame1 = np.zeros((300, 400, 3), dtype=np.uint8)
frame2 = np.zeros((300, 400, 3), dtype=np.uint8)
# Place the images within the frames
frame1[0:300, 0:350] = image1
frame2[0:300, 50:400] = image2
# Concatenate the two frames horizontally to create the combined image
combined_image = cv2.hconcat([frame1, frame2])
# Save the combined image
cv2.imwrite('combined_image.jpg', combined_image)
# Display the combined image
cv2_imshow(combined_image)
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# <PIL.Image.Image image mode=RGB size=800x300>

# %%
image = Image.open('combined_image.jpg')
new_image3 = image.resize((500, 300))
new_image3.save('combined_image_1.jpg')

# %%
new_image3
# Out:
# <PIL.Image.Image image mode=RGB size=500x300>
